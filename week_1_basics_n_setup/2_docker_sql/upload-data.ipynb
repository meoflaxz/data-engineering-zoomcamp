# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-14.0.1-cp39-cp39-win_amd64.whl (24.6 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\programdata\anaconda3\lib\site-packages (from pyarrow) (1.20.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-14.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet(r'yellow_tripdata_2021-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 1                 0.20         1.0                  N           238
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# ...                ...         ...                ...           ...
# 1369764           8.89         NaN               None           229
# 1369765           7.43         NaN               None            41
# 1369766           6.26         NaN               None            74
# 1369767          19.70         NaN               None           265
# 1369768           4.68         NaN               None            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 1                 151             2         3.00   0.50      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# ...               ...           ...          ...    ...      ...         ...
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369767           188             0        53.68   0.00      0.5        0.00
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 1                0.00                    0.3          4.30
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# ...               ...                    ...           ...
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369767          0.00                    0.3         54.48
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee
# 0                         2.5          NaN
# 1                         0.0          NaN
# 2                         0.0          NaN
# 3                         0.0          NaN
# 4                         2.5          NaN
# ...                       ...          ...
# 1369764                   NaN          NaN
# 1369765                   NaN          NaN
# 1369766                   NaN          NaN
# 1369767                   NaN          NaN
# 1369768                   NaN          NaN
#
# [1369769 rows x 19 columns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
query = """
SELECT *
FROM yellow_tripdata_trip
LIMIT 10;
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30              1.0
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28              1.0
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34              1.0
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13              1.0
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
# 5           1.60         1.0                  N           224            68
# 6           4.10         1.0                  N            95           157
# 7           5.70         1.0                  N            90            40
# 8           9.10         1.0                  N            97           129
# 9           2.70         1.0                  N           263           142
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
# 5             1          8.0    3.0      0.5        2.35           0.0
# 6             2         16.0    0.5      0.5        0.00           0.0
# 7             2         18.0    3.0      0.5        0.00           0.0
# 8             4         27.5    0.5      0.5        0.00           0.0
# 9             1         12.0    3.0      0.5        3.15           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge airport_fee
# 0                    0.3         11.80                   2.5        None
# 1                    0.3          4.30                   0.0        None
# 2                    0.3         51.95                   0.0        None
# 3                    0.3         36.35                   0.0        None
# 4                    0.3         24.36                   2.5        None
# 5                    0.3         14.15                   2.5        None
# 6                    0.3         17.30                   0.0        None
# 7                    0.3         21.80                   2.5        None
# 8                    0.3         28.80                   0.0        None
# 9                    0.3         18.95                   2.5        None

# %%
df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:767, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
#     766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#     770         if_exists=if_exists,
#     771         index=index,
#     772         index_label=index_label,
#     773         schema=schema,
#     774         chunksize=chunksize,
#     775         dtype=dtype,
#     776         method=method,
#     777         engine=engine,
#     778         **engine_kwargs,
#     779     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:1908, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1858 """
#    1859 Write records stored in a DataFrame to a SQL database.
#    1860
#    (...)
#    1904     Any additional kwargs are passed to the engine.
#    1905 """
#    1906 sql_engine = get_engine(engine)
# -> 1908 table = self.prep_table(
#    1909     frame=frame,
#    1910     name=name,
#    1911     if_exists=if_exists,
#    1912     index=index,
#    1913     index_label=index_label,
#    1914     schema=schema,
#    1915     dtype=dtype,
#    1916 )
#    1918 total_inserted = sql_engine.insert_records(
#    1919     table=table,
#    1920     con=self.con,
#    (...)
#    1927     **engine_kwargs,
#    1928 )
#    1930 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:1812, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1800             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1802 table = SQLTable(
#    1803     name,
#    1804     self,
#    (...)
#    1810     dtype=dtype,
#    1811 )
# -> 1812 table.create()
#    1813 return table
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:903, in SQLTable.create(self)
#     901 if self.exists():
#     902     if self.if_exists == "fail":
# --> 903         raise ValueError(f"Table '{self.name}' already exists.")
#     904     if self.if_exists == "replace":
#     905         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'yellow_tripdata_trip' already exists.
